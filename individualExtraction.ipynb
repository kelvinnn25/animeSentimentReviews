# %% [markdown]
# The problem I encountered was that the website would halt my scraping after a certain amount of data was collected resulting in Error 429

# %%
# !pip install requests beautifulsoup4
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import json, requests, time

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
animeDf = pd.read_csv('/content/drive/MyDrive/cis4120/group project/top50.csv')

# %%
animeDf1 = animeDf.iloc[:25,:]
animeDf2 = animeDf.iloc[25:,:]

# %%
animeDf2.info
# Out:
# <bound method DataFrame.info of     rank                                  title  score  \
# 25    26       Boku_no_Hero_Academia_3rd_Season   8.02
# 26    27                               Noragami   7.95
# 27    28                Boku_dake_ga_Inai_Machi   8.30
# 28    29                          Akame_ga_Kill   7.47
# 29    30                            Angel_Beats   8.06
# 30    31                      Nanatsu_no_Taizai   7.65
# 31    32                         Mob_Psycho_100   8.49
# 32    33                         Mirai_Nikki_TV   7.41
# 33    34                     Ansatsu_Kyoushitsu   8.08
# 34    35                    Sword_Art_Online_II   6.71
# 35    36   Shingeki_no_Kyojin__The_Final_Season   8.79
# 36    37                                Haikyuu   8.44
# 37    38                  Yakusoku_no_Neverland   8.50
# 38    39                                 Bleach   7.93
# 39    40  Kono_Subarashii_Sekai_ni_Shukufuku_wo   8.11
# ...

# %%
import time

def get_reviews(df, pages_per_link=5, delay_seconds=1):
    # Create a new DataFrame to store reviews
    reviews_df = pd.DataFrame(columns=['title', 'link', 'username', 'tags', 'review'])

    for index, row in df.iterrows():
        for page in range(1, pages_per_link + 1):
            # Modify the link by adding 'reviews?spoiler=on&p={page}' at the end
            modified_link = f"{row['link']}/reviews?spoiler=on&p={page}"
            print(f"Processing link: {modified_link}")

            # Make a request to the modified link
            response = requests.get(modified_link)

            # Check if the request was successful (status code 200)
            if response.status_code == 200:
                print(f"Successfully fetched page {page}")
                # Parse the HTML content of the page
                soup = BeautifulSoup(response.content, 'html.parser')

                # Select review elements on the page
                review_elements = soup.select('.review-element.js-review-element')

                # Extract and store each review separately
                for element in review_elements:
                    # Extract username, tags, and review text
                    tags_element = element.select_one('.tags')
                    review_text_element = element.select_one('.text')


                    tags = tags_element.text.strip()
                    review_text = review_text_element.text.strip() if review_text_element else None

                    reviews_df = reviews_df.append({
                        'title': row['title'],
                        'link': row['link'],
                        'tags': tags,
                        'review': review_text
                    }, ignore_index=True)
                # Introduce a delay before the next request
                time.sleep(delay_seconds)

            else:
                print(f"Failed to fetch page {page}. Status code: {response.status_code}")

    return reviews_df

# Assuming your original DataFrame is named 'top50_df'
# Call the function to get and add reviews from 25 pages per link with a delay of 1 second
reviews_df = get_reviews(animeDf1, pages_per_link=5, delay_seconds=1)
# Out:
# Processing link: https://myanimelist.net/anime/16498/Shingeki_no_Kyojin/reviews?spoiler=on&p=1
# Successfully fetched page 1
# <ipython-input-15-b7dde9a7b9fa>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reviews_df = reviews_df.append({
# <ipython-input-15-b7dde9a7b9fa>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reviews_df = reviews_df.append({
# <ipython-input-15-b7dde9a7b9fa>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reviews_df = reviews_df.append({
# <ipython-input-15-b7dde9a7b9fa>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reviews_df = reviews_df.append({
# ...

# %%
reviews_df.info
# Out:
# <bound method DataFrame.info of                                    title  \
# 0                     Shingeki_no_Kyojin
# 1                     Shingeki_no_Kyojin
# 2                     Shingeki_no_Kyojin
# 3                     Shingeki_no_Kyojin
# 4                     Shingeki_no_Kyojin
# ...                                  ...
# 2175  Shingeki_no_Kyojin_Season_3_Part_2
# 2176  Shingeki_no_Kyojin_Season_3_Part_2
# 2177  Shingeki_no_Kyojin_Season_3_Part_2
# 2178  Shingeki_no_Kyojin_Season_3_Part_2
# 2179  Shingeki_no_Kyojin_Season_3_Part_2
#
#                                                    link username  \
# 0     https://myanimelist.net/anime/16498/Shingeki_n...      NaN
# 1     https://myanimelist.net/anime/16498/Shingeki_n...      NaN
# 2     https://myanimelist.net/anime/16498/Shingeki_n...      NaN
# 3     https://myanimelist.net/anime/16498/Shingeki_n...      NaN
# 4     https://myanimelist.net/anime/16498/Shingeki_n...      NaN
# ...

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Assuming df_reviews is your DataFrame
csv_content = reviews_df.to_csv(index=False)

# Specify the folder path in your Google Drive
folder_path = '/content/drive/MyDrive/'

# Specify the file path within the folder
file_path = folder_path + 'reviews1.csv'

# Write the CSV content to the specified file path
with open(file_path, 'w') as f:
    f.write(csv_content)

print(f"File 'reviews1.csv' has been saved to Google Drive at: {file_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# File 'reviews1.csv' has been saved to Google Drive at: /content/drive/MyDrive/reviews1.csv

# %%
reviews_df2 = get_reviews(animeDf2, pages_per_link=5, delay_seconds=1)

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Assuming df_reviews is your DataFrame
csv_content = reviews_df2.to_csv(index=False)

# Specify the folder path in your Google Drive
folder_path = '/content/drive/MyDrive/'

# Specify the file path within the folder
file_path = folder_path + 'reviews2.csv'

# Write the CSV content to the specified file path
with open(file_path, 'w') as f:
    f.write(csv_content)

print(f"File 'reviews2.csv' has been saved to Google Drive at: {file_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# File 'reviews2.csv' has been saved to Google Drive at: /content/drive/MyDrive/reviews2.csv

# %% [markdown]
# https://myanimelist.net/anime/28223/Death_Parade/reviews?spoiler=on&p=5
# https://myanimelist.net/anime/33352/Violet_Evergarden/reviews?spoiler=on&p=1
# https://myanimelist.net/anime/33352/Violet_Evergarden/reviews?spoiler=on&p=2
# https://myanimelist.net/anime/33352/Violet_Evergarden/reviews?spoiler=on&p=3
# https://myanimelist.net/anime/33352/Violet_Evergarden/reviews?spoiler=on&p=4
# https://myanimelist.net/anime/33352/Violet_Evergarden/reviews?spoiler=on&p=5
# https://myanimelist.net/anime/6702/Fairy_Tail/reviews?spoiler=on&p=1
# https://myanimelist.net/anime/6702/Fairy_Tail/reviews?spoiler=on&p=2
# https://myanimelist.net/anime/6702/Fairy_Tail/reviews?spoiler=on&p=3
# https://myanimelist.net/anime/6702/Fairy_Tail/reviews?spoiler=on&p=4
# https://myanimelist.net/anime/6702/Fairy_Tail/reviews?spoiler=on&p=5
# https://myanimelist.net/anime/38524/Shingeki_no_Kyojin_Season_3_Part_2/reviews?spoiler=on&p=5
# https://myanimelist.net/anime/4224/Toradora/reviews?spoiler=on&p=1
# https://myanimelist.net/anime/4224/Toradora/reviews?spoiler=on&p=2
# https://myanimelist.net/anime/4224/Toradora/reviews?spoiler=on&p=3
# https://myanimelist.net/anime/4224/Toradora/reviews?spoiler=on&p=4
# https://myanimelist.net/anime/4224/Toradora/reviews?spoiler=on&p=5
# https://myanimelist.net/anime/23273/Shigatsu_wa_Kimi_no_Uso/reviews?spoiler=on&p=1
# https://myanimelist.net/anime/23273/Shigatsu_wa_Kimi_no_Uso/reviews?spoiler=on&p=2
# https://myanimelist.net/anime/23273/Shigatsu_wa_Kimi_no_Uso/reviews?spoiler=on&p=3
# https://myanimelist.net/anime/23273/Shigatsu_wa_Kimi_no_Uso/reviews?spoiler=on&p=4
# https://myanimelist.net/anime/23273/Shigatsu_wa_Kimi_no_Uso/reviews?spoiler=on&p=5
# https://myanimelist.net/anime/31240/Re_Zero_kara_Hajimeru_Isekai_Seikatsu/reviews?spoiler=on&p=1
# https://myanimelist.net/anime/31240/Re_Zero_kara_Hajimeru_Isekai_Seikatsu/reviews?spoiler=on&p=2
# https://myanimelist.net/anime/31240/Re_Zero_kara_Hajimeru_Isekai_Seikatsu/reviews?spoiler=on&p=3
# https://myanimelist.net/anime/31240/Re_Zero_kara_Hajimeru_Isekai_Seikatsu/reviews?spoiler=on&p=4
# https://myanimelist.net/anime/31240/Re_Zero_kara_Hajimeru_Isekai_Seikatsu/reviews?spoiler=on&p=5

# %%
failed_urls = [
    "https://myanimelist.net/anime/28223/Death_Parade/reviews?spoiler=on&p=5",
    "https://myanimelist.net/anime/33352/Violet_Evergarden/reviews?spoiler=on&p=1",
    "https://myanimelist.net/anime/33352/Violet_Evergarden/reviews?spoiler=on&p=2",
    "https://myanimelist.net/anime/33352/Violet_Evergarden/reviews?spoiler=on&p=3",
    "https://myanimelist.net/anime/33352/Violet_Evergarden/reviews?spoiler=on&p=4",
    "https://myanimelist.net/anime/33352/Violet_Evergarden/reviews?spoiler=on&p=5",
    "https://myanimelist.net/anime/6702/Fairy_Tail/reviews?spoiler=on&p=1",
    "https://myanimelist.net/anime/6702/Fairy_Tail/reviews?spoiler=on&p=2",
    "https://myanimelist.net/anime/6702/Fairy_Tail/reviews?spoiler=on&p=3",
    "https://myanimelist.net/anime/6702/Fairy_Tail/reviews?spoiler=on&p=4",
    "https://myanimelist.net/anime/6702/Fairy_Tail/reviews?spoiler=on&p=5",
    "https://myanimelist.net/anime/38524/Shingeki_no_Kyojin_Season_3_Part_2/reviews?spoiler=on&p=5",
    "https://myanimelist.net/anime/4224/Toradora/reviews?spoiler=on&p=1",
    "https://myanimelist.net/anime/4224/Toradora/reviews?spoiler=on&p=2",
    "https://myanimelist.net/anime/4224/Toradora/reviews?spoiler=on&p=3",
    "https://myanimelist.net/anime/4224/Toradora/reviews?spoiler=on&p=4",
    "https://myanimelist.net/anime/4224/Toradora/reviews?spoiler=on&p=5",
    "https://myanimelist.net/anime/23273/Shigatsu_wa_Kimi_no_Uso/reviews?spoiler=on&p=1",
    "https://myanimelist.net/anime/23273/Shigatsu_wa_Kimi_no_Uso/reviews?spoiler=on&p=2",
    "https://myanimelist.net/anime/23273/Shigatsu_wa_Kimi_no_Uso/reviews?spoiler=on&p=3",
    "https://myanimelist.net/anime/23273/Shigatsu_wa_Kimi_no_Uso/reviews?spoiler=on&p=4",
    "https://myanimelist.net/anime/23273/Shigatsu_wa_Kimi_no_Uso/reviews?spoiler=on&p=5",
    "https://myanimelist.net/anime/31240/Re_Zero_kara_Hajimeru_Isekai_Seikatsu/reviews?spoiler=on&p=1",
    "https://myanimelist.net/anime/31240/Re_Zero_kara_Hajimeru_Isekai_Seikatsu/reviews?spoiler=on&p=2",
    "https://myanimelist.net/anime/31240/Re_Zero_kara_Hajimeru_Isekai_Seikatsu/reviews?spoiler=on&p=3",
    "https://myanimelist.net/anime/31240/Re_Zero_kara_Hajimeru_Isekai_Seikatsu/reviews?spoiler=on&p=4",
    "https://myanimelist.net/anime/31240/Re_Zero_kara_Hajimeru_Isekai_Seikatsu/reviews?spoiler=on&p=5",
]

# %%
def get_failed_reviews(links, delay_seconds=1):
    # Create a new DataFrame to store reviews
    reviews_df = pd.DataFrame(columns=['title', 'link', 'tags', 'review'])

    for link in links:

          current_link = f"{link}"
          print(f"Processing link: {current_link}")

          # Make a request to the current link
          response = requests.get(current_link)

          # Check if the request was successful (status code 200)
          if response.status_code == 200:
              print(f"Successfully fetched link {link}")
              # Parse the HTML content of the page
              soup = BeautifulSoup(response.content, 'html.parser')

              # Select review elements on the page
              review_elements = soup.select('.review-element.js-review-element')

              # Extract and store each review separately
              for element in review_elements:
                  # Extract username, tags, and review text
                  tags_element = element.select_one('.tags')
                  review_text_element = element.select_one('.text')

                  tags = tags_element.text.strip()
                  review_text = review_text_element.text.strip() if review_text_element else None

                  reviews_df = reviews_df.append({
                      'title': link.split('/')[-2],  # Extract title from the link
                      'link': link,
                      'tags': tags,
                      'review': review_text
                  }, ignore_index=True)
              # Introduce a delay before the next request
              time.sleep(delay_seconds)

          else:
              print(f"Failed to fetch link {link}. Status code: {response.status_code}")

    return reviews_df

# %%
reviews_df3 = get_failed_reviews(failed_urls, delay_seconds=1)
# Out:
# Processing link: https://myanimelist.net/anime/28223/Death_Parade/reviews?spoiler=on&p=5
# Successfully fetched link https://myanimelist.net/anime/28223/Death_Parade/reviews?spoiler=on&p=5
# <ipython-input-24-c0fc269417c7>:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reviews_df = reviews_df.append({
# <ipython-input-24-c0fc269417c7>:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reviews_df = reviews_df.append({
# <ipython-input-24-c0fc269417c7>:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reviews_df = reviews_df.append({
# <ipython-input-24-c0fc269417c7>:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
reviews_df3.info
# Out:
# <bound method DataFrame.info of                                      title  \
# 0                             Death_Parade
# 1                             Death_Parade
# 2                             Death_Parade
# 3                             Death_Parade
# 4                             Death_Parade
# ..                                     ...
# 535  Re_Zero_kara_Hajimeru_Isekai_Seikatsu
# 536  Re_Zero_kara_Hajimeru_Isekai_Seikatsu
# 537  Re_Zero_kara_Hajimeru_Isekai_Seikatsu
# 538  Re_Zero_kara_Hajimeru_Isekai_Seikatsu
# 539  Re_Zero_kara_Hajimeru_Isekai_Seikatsu
#
#                                                   link  \
# 0    https://myanimelist.net/anime/28223/Death_Para...
# 1    https://myanimelist.net/anime/28223/Death_Para...
# 2    https://myanimelist.net/anime/28223/Death_Para...
# 3    https://myanimelist.net/anime/28223/Death_Para...
# 4    https://myanimelist.net/anime/28223/Death_Para...
# ..                                                 ...
# ...

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Assuming df_reviews is your DataFrame
csv_content = reviews_df3.to_csv(index=False)

# Specify the folder path in your Google Drive
folder_path = '/content/drive/MyDrive/'

# Specify the file path within the folder
file_path = folder_path + 'reviews3.csv'

# Write the CSV content to the specified file path
with open(file_path, 'w') as f:
    f.write(csv_content)

print(f"File 'reviews3.csv' has been saved to Google Drive at: {file_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# File 'reviews3.csv' has been saved to Google Drive at: /content/drive/MyDrive/reviews3.csv

# %% [markdown]
# Combinging all CSV files

# %%
animeDf = pd.read_csv('/content/drive/MyDrive/cis4120/group project/top50.csv')
reviews1 = pd.read_csv('/content/drive/MyDrive/cis4120/group project/reviews1.csv')
reviews2 = pd.read_csv('/content/drive/MyDrive/cis4120/group project/reviews2.csv')
reviews3 = pd.read_csv('/content/drive/MyDrive/cis4120/group project/reviews3.csv')

# %%
reviews1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2180 entries, 0 to 2179
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     2180 non-null   object
#  1   link      2180 non-null   object
#  2   username  0 non-null      float64
#  3   tags      2180 non-null   object
#  4   review    2180 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 85.3+ KB

# %%
reviews2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2280 entries, 0 to 2279
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     2280 non-null   object
#  1   link      2280 non-null   object
#  2   username  0 non-null      float64
#  3   tags      2280 non-null   object
#  4   review    2280 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 89.2+ KB

# %%
appended_df = pd.concat([reviews1, reviews2], ignore_index=True)
appended_df.drop(columns=["username"],inplace=True)
reviews = pd.concat([appended_df,reviews3],ignore_index=True)

# %%
merged_df = pd.merge(reviews, animeDf, on='title', how='left')
# Display the resulting dataframe
print(merged_df)
# Out:
#                                       title  \
# 0                        Shingeki_no_Kyojin
# 1                        Shingeki_no_Kyojin
# 2                        Shingeki_no_Kyojin
# 3                        Shingeki_no_Kyojin
# 4                        Shingeki_no_Kyojin
# ...                                     ...
# 4995  Re_Zero_kara_Hajimeru_Isekai_Seikatsu
# 4996  Re_Zero_kara_Hajimeru_Isekai_Seikatsu
# 4997  Re_Zero_kara_Hajimeru_Isekai_Seikatsu
# 4998  Re_Zero_kara_Hajimeru_Isekai_Seikatsu
# 4999  Re_Zero_kara_Hajimeru_Isekai_Seikatsu
#
#                                                  link_x  \
# 0     https://myanimelist.net/anime/16498/Shingeki_n...
# 1     https://myanimelist.net/anime/16498/Shingeki_n...
# 2     https://myanimelist.net/anime/16498/Shingeki_n...
# 3     https://myanimelist.net/anime/16498/Shingeki_n...
# 4     https://myanimelist.net/anime/16498/Shingeki_n...
# ...                                                 ...
# ...

# %%
merged_df['tags'] = merged_df['tags'].str.split('Preliminary').str[0].str.strip()

# %%
merged_df
# Out:
#                                       title  \
# 0                        Shingeki_no_Kyojin
# 1                        Shingeki_no_Kyojin
# 2                        Shingeki_no_Kyojin
# 3                        Shingeki_no_Kyojin
# 4                        Shingeki_no_Kyojin
# ...                                     ...
# 4995  Re_Zero_kara_Hajimeru_Isekai_Seikatsu
# 4996  Re_Zero_kara_Hajimeru_Isekai_Seikatsu
# 4997  Re_Zero_kara_Hajimeru_Isekai_Seikatsu
# 4998  Re_Zero_kara_Hajimeru_Isekai_Seikatsu
# 4999  Re_Zero_kara_Hajimeru_Isekai_Seikatsu
#
#                                                  link_x             tags  \
# 0     https://myanimelist.net/anime/16498/Shingeki_n...      Recommended
# 1     https://myanimelist.net/anime/16498/Shingeki_n...      Recommended
# 2     https://myanimelist.net/anime/16498/Shingeki_n...      Recommended
# 3     https://myanimelist.net/anime/16498/Shingeki_n...   Mixed Feelings
# ...

# %%
merged_df.drop(columns=['link_y','link_x'],inplace=True)
reorder = ['title', 'rank', 'score', 'tags', 'review']
merged_df = merged_df[reorder]

# %%
merged_df = merged_df.sort_values('rank')

# %%
merged_df = merged_df.reset_index()

# %%
merged_df.drop(columns=["level_0"],inplace=True)
merged_df
# Out:
#                    title  rank  score             tags  \
# 0     Shingeki_no_Kyojin     1   8.54      Recommended
# 1     Shingeki_no_Kyojin     1   8.54      Recommended
# 2     Shingeki_no_Kyojin     1   8.54   Mixed Feelings
# 3     Shingeki_no_Kyojin     1   8.54      Recommended
# 4     Shingeki_no_Kyojin     1   8.54      Recommended
# ...                  ...   ...    ...              ...
# 4995          Fairy_Tail    50   7.57  Not Recommended
# 4996          Fairy_Tail    50   7.57      Recommended
# 4997          Fairy_Tail    50   7.57      Recommended
# 4998          Fairy_Tail    50   7.57  Not Recommended
# 4999          Fairy_Tail    50   7.57  Not Recommended
#
#                                                  review
# 0     Oh dear Shingeki no Kyojin, where do I even be...
# 1     Attack on Titan Review:\n\r\nI was well aware ...
# 2     Why Shingeki no Kyojin might not be the epic y...
# 3     (This is my first review, so bear with me.) \n...
# ...

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Assuming df_reviews is your DataFrame
csv_content = merged_df.to_csv(index=False)

# Specify the folder path in your Google Drive
folder_path = '/content/drive/MyDrive/'

# Specify the file path within the folder
file_path = folder_path + 'anime_reviews.csv'

# Write the CSV content to the specified file path
with open(file_path, 'w') as f:
    f.write(csv_content)

print(f"File 'anime_reviews.csv' has been saved to Google Drive at: {file_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# File 'anime_reviews.csv' has been saved to Google Drive at: /content/drive/MyDrive/anime_reviews.csv
